# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
df=pd.read_csv("zomato_dataset.csv")

# %%
df
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
char=df[(df["Delivery Rating"]>4)&(df["Dining Rating"]>4)&(df["Delivery Votes"]>100)&(df["Dining Votes"]>100)].value_counts().drop_duplicates()
char
# Out:
# Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  Delivery Votes  Cuisine    Place Name   City       Item Name                      Best Seller     Votes  Prices
# Kuduk Chicken    4.2            4.1              309           869             Fast Food  Gomti Nagar  Lucknow    Kuduk Special Chicken Popcorn  CHEF'S SPECIAL  78     130.0     3
# Annamaya         4.3            4.1              187           952             Beverages  Byculla      Mumbai     Chilli Paneer Dry              BESTSELLER      21     330.0     2
# Captain Kunafa   4.1            4.1              208           699             Turkish    Malakpet     Hyderabad  Almonds Baklava carrot pieces  CHEF'S SPECIAL  5      300.0     1
# Name: count, dtype: int64

# %%
# import plotly.express as px
# fig = px.scatter_geo(df,locations="City",locationmode="country names",size="Votes",color="City", hover_name="City", hover_data=["Votes"],projection="natural earth",height=400)
# fig.show()

# %%
# plt.pie(df.loc[],labels=char,colors=["blue","green","orange","pink"],autopct='%1.2f%%')

# %%
df[df["Restaurant Name"]=="Captain Kunafa"]#,"Annamaya","Kuduk Chicken"
# Out:
#      Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 9027  Captain Kunafa            4.1              4.1           208
# 9028  Captain Kunafa            4.1              4.1           208
# 9029  Captain Kunafa            4.1              4.1           208
# 9030  Captain Kunafa            4.1              4.1           208
# 9031  Captain Kunafa            4.1              4.1           208
# 9032  Captain Kunafa            4.1              4.1           208
# 9033  Captain Kunafa            4.1              4.1           208
# 9034  Captain Kunafa            4.1              4.1           208
# 9035  Captain Kunafa            4.1              4.1           208
# 9036  Captain Kunafa            4.1              4.1           208
# 9037  Captain Kunafa            4.1              4.1           208
# 9038  Captain Kunafa            4.1              4.1           208
# 9039  Captain Kunafa            4.1              4.1           208
# ...

# %%
var=df["Votes"].sort_values(ascending=False).head(100)
var
# Out:
# 12417    9750
# 12451    9750
# 11182    8613
# 11146    8613
# 6131     7931
#          ...
# 68473    1732
# 68397    1732
# 11251    1702
# 11149    1696
# 11187    1696
# Name: Votes, Length: 100, dtype: int64

# %%
px.pie(values=df.loc[var,"Votes"],names=df.loc[var,"Restaurant Name"],title="TOP 20 RESTAURENTS")

# %%
pri=df["Prices"].sort_values(ascending=False).head(10)
Vo=df["Votes"].sort_values(ascending=False).head(10)

# %%
# px.scatter(x=pri,y=Vo,color=["hotpink","blue"])
# sns.swarmplot(data=fli,x="year",y="passengers",hue="month")
sns.swarmplot(data=df,x=df["Prices"].head(15),y=df["Votes"].head(200))
# Out:
# <Axes: xlabel='Prices', ylabel='Votes'>

# %%
val=df[df["Best Seller"].isin(['BESTSELLER',"CHEF'S SPECIAL","MUST TRY"])].head(50)
val
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# 5                  Doner King            3.9              4.2            39
# 6                  Doner King            3.9              4.2            39
# 7                  Doner King            3.9              4.2            39
# 11                 Doner King            3.9              4.2            39
# 12                 Doner King            3.9              4.2            39
# 13                 Doner King            3.9              4.2            39
# 15                 Doner King            3.9              4.2            39
# ...

# %%
# data_canada = px.data.gapminder().query("country == 'Canada'")
# fig = px.bar(data_canada, x='year', y='pop')
# # fig.show(

fig = sns.barplot(val, x='Best Seller', y='Votes',hue="Votes")

# %%
this = df["Votes"].sort_values(ascending=False).head(20).drop_duplicates().index
this
# Out:
# Index([12417, 11182, 6131, 11184, 12416, 110006, 13322, 7938, 110559, 6136], dtype='int64')

# %%
df.loc[this,:]
# Out:
#                     Restaurant Name  Dining Rating  Delivery Rating  \
# 12417                        Mehfil            4.1              4.0
# 11182                      Bawarchi            4.2              4.1
# 6131               Lucky Restaurant            4.1              4.0
# 11184                      Bawarchi            4.2              4.1
# 12416                        Mehfil            4.1              4.0
# 110006               Lazeez Biryani            3.6              3.7
# 13322   Al Rabea Al Arabi Cafeteria            3.2              4.4
# 7938               4M Biryani House            4.1              4.2
# 110559           Zam Zam Restaurant            4.2              4.3
# 6136               Lucky Restaurant            4.1              4.0
#
#         Dining Votes  Delivery Votes      Cuisine         Place Name  \
# 12417              0               0  North Indian       Narayanguda
# 11182              0               0      Desserts       RTC X roads
# ...

# %%
px.pie(values=df.loc[this,"Votes"],names=df.loc[this,"Item Name"],title="TOP ITEMS BY VOTES")

# %%
his = df["Delivery Rating"].sort_values(ascending=False).head(100000).drop_duplicates().index
his
# Out:
# Index([6776, 11518, 122552, 112336, 74232, 84997, 9829, 200, 121520, 85451], dtype='int64')

# %%
px.scatter(data_frame=his, x=df.loc[his,"Item Name"], y=df.loc[his,'Delivery Rating'], color=df.loc[his,"Item Name"])

# %%
df.loc[this,:]
# Out:
#                     Restaurant Name  Dining Rating  Delivery Rating  \
# 12417                        Mehfil            4.1              4.0
# 11182                      Bawarchi            4.2              4.1
# 6131               Lucky Restaurant            4.1              4.0
# 11184                      Bawarchi            4.2              4.1
# 12416                        Mehfil            4.1              4.0
# 110006               Lazeez Biryani            3.6              3.7
# 13322   Al Rabea Al Arabi Cafeteria            3.2              4.4
# 7938               4M Biryani House            4.1              4.2
# 110559           Zam Zam Restaurant            4.2              4.3
# 6136               Lucky Restaurant            4.1              4.0
#
#         Dining Votes  Delivery Votes      Cuisine         Place Name  \
# 12417              0               0  North Indian       Narayanguda
# 11182              0               0      Desserts       RTC X roads
# ...

# %%
px.pie(values=df.loc[this,"Votes"],names=df.loc[this,"Cuisine "],title="TOP CUISINE BY VOTES")
