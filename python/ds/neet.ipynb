# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("neet_data.csv")

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df["retweet_count"].sort_values(ascending=False)
# Out:
# 32860    614304
# 33262    581097
# 35111    381458
# 32585    204348
# 38044    192350
#           ...
# 47347         0
# 47348         0
# 47349         0
# 47351         0
# 47332         0
# Name: retweet_count, Length: 47381, dtype: int64

# %%
top10=df["retweet_count"].sort_values(ascending=False).head(10).index

# %%
df.loc[32860,["source","user_name","user_url","created_at","retweet_count","tweet","user_follower_count"]]
# Out:
# source                                                Twitter for iPhone
# user_name                           \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# user_url                                         https://t.co/cHZdP4uOdu
# created_at                                           2020-11-08 05:30:01
# retweet_count                                                     614304
# tweet                  RT @JoeBiden: America, I\xe2\x80\x99m honored ...
# user_follower_count                                                   62
# Name: 32860, dtype: object

# %%
df.loc[top10,"retweet_count"].sum()
"THE TOP 10 RETWEET SUM IS 2652225"
# Out:
# 'THE TOP 10 RETWEET SUM IS 2652225'

# %%
an=df[df["source"]=="Twitter for Android"].index
df.loc[an,'retweet_count'].sum()
'SUM OF ALL DONE BY TWITTER FOR ANDROID IS 9386742'
# Out:
# 'SUM OF ALL DONE BY TWITTER FOR ANDROID IS 9386742'

# %%
df["user_follower_count"].max()
df[df.loc[:,"user_follower_count"]==13934355]
# Out:
#                 created_at  retweet_count                          source  \
# 44355  2020-11-01 10:49:41             15  Twitter Media Studio - LiveCut
# 44367  2020-11-01 10:45:04             24  Twitter Media Studio - LiveCut
# 44424  2020-11-01 10:01:49             11  Twitter Media Studio - LiveCut
# 44436  2020-11-01 09:57:24             14  Twitter Media Studio - LiveCut
#
#         user_id user_name                                   user_description  \
# 44355  37034483      NDTV  Breaking news alerts from India.\n\nInstagram:...
# 44367  37034483      NDTV  Breaking news alerts from India.\n\nInstagram:...
# 44424  37034483      NDTV  Breaking news alerts from India.\n\nInstagram:...
# 44436  37034483      NDTV  Breaking news alerts from India.\n\nInstagram:...
#
#        user_follower_count  user_friends_count user_location  user_verified  \
# 44355             13934355                  15         India           True
# ...

# %%
df.loc[44367,["user_name","user_location"]]
# Out:
# user_name         NDTV
# user_location    India
# Name: 44367, dtype: object

# %%
val=df["user_follower_count"]/df['user_friends_count']

# %%
df["follower_friend_ratio"]=val

# %%
df.isnull().sum()
# Out:
# created_at                   0
# retweet_count                0
# source                      19
# user_id                      0
# user_name                    1
# user_description         10871
# user_follower_count          0
# user_friends_count           0
# user_location            21134
# user_verified                0
# user_url                 38101
# tweet                        0
# length_of_tweet              0
# follower_friend_ratio      147
# dtype: int64

# %%
nain=df[df["user_description"].isnull()].index
df.loc[nain,'user_description']="Twitter user"

# %%
df.drop(["source","user_name","user_location","user_url","follower_friend_ratio"],axis=1,inplace=True)

# %%
df.insert(loc=2,column="is_allow",value=None)

# %%
# df.drop("tweet",axis=1,inplace=True)
df
# Out:
#                 created_at  retweet_count is_allow              user_id  \
# 0      2020-10-31 14:10:28            141     None  1250294694937915394
# 1      2020-10-31 14:10:11              1     None             57059492
# 2      2020-10-31 14:09:48            141     None           1016022678
# 3      2020-10-31 14:09:41            141     None  1085818329816883201
# 4      2020-10-31 14:09:22              0     None  1227501071490113537
# ...                    ...            ...      ...                  ...
# 47376  2020-10-30 15:29:35              0     None  1168840190426632192
# 47377  2020-10-30 15:29:35           1700     None           1696615807
# 47378  2020-10-30 15:28:59            167     None  1313330869113745413
# 47379  2020-10-30 15:28:37            270     None  1161551282995388416
# 47380  2020-10-30 15:28:14              0     None  1211810532006612992
#
#                                         user_description  user_follower_count  \
# ...

# %%
st=df["created_at"].str
st

# %%
st[0:4]
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 47376    2020
# 47377    2020
# 47378    2020
# 47379    2020
# 47380    2020
# Name: created_at, Length: 47381, dtype: object

# %%
st[5:7]
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 47376    10
# 47377    10
# 47378    10
# 47379    10
# 47380    10
# Name: created_at, Length: 47381, dtype: object
