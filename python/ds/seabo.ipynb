# %%
import seaborn as sns

# %%
df=sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df[df["sex"]=="Female"]["body_mass_g"].mode()
# Out:
# 0    3700.0
# Name: body_mass_g, dtype: float64

# %%
se=df[df["sex"].isna()].index
df.loc[se,:]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# ...

# %%
se
# Out:
# Index([3, 8, 9, 10, 11, 47, 246, 286, 324, 336, 339], dtype='int64')

# %%
df.loc[[8,10,11,47,],"sex"]="Female"
df.loc[[3,9,246,286,324,336,339],"sex"]="Male"

# %%
df[df["body_mass_g"].isna()].index
# Out:
# Index([3, 339], dtype='int64')

# %%
df.loc[[3, 339],"body_mass_g"]=3950.0

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df["flipper_length_mm"].mode()
# Out:
# 0    190.0
# Name: flipper_length_mm, dtype: float64

# %%
df.loc[[3, 339],"bill_length_mm"]=41.1

# %%
df.loc[[3, 339],"bill_depth_mm"]=17.0

# %%
df.loc[[3,339],"flipper_length_mm"]=190.0

# %%
df.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
fli=sns.load_dataset("flights")
fli
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=fli,x="year",y="passengers",hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.barplot(data=fli,x="year",y="passengers",hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.catplot(data=fli,x="year",y="passengers",hue="month")

# %%
sns.pairplot(fli,hue="passengers")

# %%
sns.countplot(data=fli,x="year",hue="month")
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
sns.barplot(data=fli,x="month",y="passengers",hue="year")
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.displot(data=fli,x="year",y="passengers",hue="month")

# %%
sns.boxenplot(data=fli,x="year",y="passengers",hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.dogplot()

# %%
sns.jointplot(data=fli,x="year",y="passengers",hue="month")

# %%
sns.jointplot(data=fli,x="year",y="passengers",hue="month")

# %%
sns.pointplot(data=fli)
# Out:
# <Axes: >

# %%
sns.violinplot(data=fli,x="year",y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.swarmplot(data=fli,x="year",y="passengers",hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.residplot(data=fli,x="year",y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.rugplot(data=fli,x="year",y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
fli
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fli.pivot_table(values="passengers",index="year",columns="month")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10352\2449090940.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fli.pivot_table(values="passengers",index="year",columns="month")
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# year
# 1949   112.0  118.0  132.0  129.0  121.0  135.0  148.0  148.0  136.0  119.0
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
# 1954   204.0  188.0  235.0  227.0  234.0  264.0  302.0  293.0  259.0  229.0
# 1955   242.0  233.0  267.0  269.0  270.0  315.0  364.0  347.0  312.0  274.0
# ...

# %%
fli.pivot_table(values="passengers",index="month",columns="year")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10352\26375892.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fli.pivot_table(values="passengers",index="month",columns="year")
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
fli.pivot_table(values="passengers",index="month",columns="year").sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10352\3041887063.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fli.pivot_table(values="passengers",index="month",columns="year").sum()
# year
# 1949    1520.0
# 1950    1676.0
# 1951    2042.0
# 1952    2364.0
# 1953    2700.0
# 1954    2867.0
# 1955    3408.0
# 1956    3939.0
# 1957    4421.0
# 1958    4572.0
# 1959    5140.0
# 1960    5714.0
# dtype: float64
