# %% [markdown]
# Data Ingestion- Data ingestion is the automated process of transporting, cleansing, and loading data from various sources (databases, APIs, files) into a centralized repository, such as a data warehouse or lake, for analysis and storage.

# %%
# text loader 
from langchain_community.document_loaders import TextLoader
loader = TextLoader('textdata.txt')
# Out:
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
text= loader.load() # Reads the file and convert into langchain document format 
text
# Out:
# [Document(metadata={'source': 'textdata.txt'}, page_content='Data ingestion is the automated process of transporting, cleansing, and loading data from various sources (databases, APIs, files)\ninto a centralized repository, such as a data warehouse or lake, for analysis and storage. ')]

# %%
from langchain_community.document_loaders import PyPDFLoader
loader= PyPDFLoader('research_k.pdf')
docs= loader.load()
docs
# Out:
# [Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-12-06T12:36:38+05:30', 'author': 'khush', 'comments': '', 'company': '', 'keywords': '', 'moddate': '2025-12-06T12:36:38+05:30', 'sourcemodified': "D:20251206123638+05'30'", 'subject': '', 'title': '', 'trapped': '/False', 'source': 'research_k.pdf', 'total_pages': 46, 'page': 0, 'page_label': '1'}, page_content='1\nTitle: Hybrid Deep Learning Architecture Integrating ConvNeXtV2, Swin\nTransformer, and CBAM for Enhanced Multiclass Brain Tumor Classification in\nMRIImages\nFirst Author Name: Khushvir Singh\nResearchScholar,DepartmentofComputerscienceandEngineering,I.K.Gujral\nPunjabTechnicalUniversity,Jalandhar-KapurthalaHighway,VPO-Ibban,\nKapurthala-144603,Punjab,India\nE-mail:Khushvirsingh100@gmail.com\nPhone:91-7658048680\nSecond Author Name:Dr. Pooja Sharma\nAssistantProffesor,DepartmentofComputerscienceand Engineering,I.K.Gujral\nPunjabTechnicalUniversity,Jalandhar-KapurthalaHighway,VPO-Ibban,\nKa
# ...

# %%
# !pip install langchain-text-splitters

# %%
from langchain_text_splitters  import RecursiveCharacterTextSplitter
text_splitter= RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# %%
# import langchain
# print(langchain.__version__)

# %%
# !pip install -U langchain

# %%
document = text_splitter.split_documents(docs)

# %%
document
# Out:
# [Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2025-12-06T12:36:38+05:30', 'author': 'khush', 'comments': '', 'company': '', 'keywords': '', 'moddate': '2025-12-06T12:36:38+05:30', 'sourcemodified': "D:20251206123638+05'30'", 'subject': '', 'title': '', 'trapped': '/False', 'source': 'research_k.pdf', 'total_pages': 46, 'page': 0, 'page_label': '1'}, page_content='1\nTitle: Hybrid Deep Learning Architecture Integrating ConvNeXtV2, Swin\nTransformer, and CBAM for Enhanced Multiclass Brain Tumor Classification in\nMRIImages\nFirst Author Name: Khushvir Singh\nResearchScholar,DepartmentofComputerscienceandEngineering,I.K.Gujral\nPunjabTechnicalUniversity,Jalandhar-KapurthalaHighway,VPO-Ibban,\nKapurthala-144603,Punjab,India\nE-mail:Khushvirsingh100@gmail.com\nPhone:91-7658048680\nSecond Author Name:Dr. Pooja Sharma\nAssistantProffesor,DepartmentofComputerscienceand Engineering,I.K.Gujral\nPunjabTechnicalUniversity,Jalandhar-KapurthalaHighway,VPO-Ibban,\nKa
# ...

# %%
# embeddings-ollama 
from langchain_ollama import OllamaEmbeddings # convert text -> to vector(numbers)
from langchain_community.vectorstores import Chroma

# %%
def cleantext(text):
    return text.encode("utf-8","ignore").decode("utf-8","ignore")

# cleaned= [cleantext(i.page_content) for i in document]
cleaned_docs=[]
for d in document:
    d.page_content= cleantext(d.page_content)
    cleaned_docs.append(d)

# %%
emb= OllamaEmbeddings(model="nomic-embed-text") # qwen3-embedding:0.6b

# %%
db= Chroma.from_documents(cleaned_docs, emb)

# %%
query="The FCMAE framework introduces a fully convolutional"

# %%
r= db.similarity_search(query)
r[0].page_content
# Out:
# '5\n.\nFigure 1. The FCMAE framework introduces a fully convolutional masked\nautoencoder designed to learn robust visual representations. The system is composed\nof a ConvNeXt-based encoder that operates using sparse convolutions and a\nlightweight ConvNeXt block serving as the decoder. The architecture is intentionally\nasymmetric: the encoder processes only the unmasked portions of the input image,\nwhile the decoder reconstructs the full image by combining the encoded visible\npatches with the corresponding mask tokens. Importantly, the reconstruction loss is\nappliedsolelytothemasked regions,ensuringthat themodel focuseson inferring the\nmissinginformationratherthanrelyingonthevisiblepixels.\n3.2 Fully Convolutional Masked Autoencoder (FCMAE)\nTheproposedframeworkconsistsoftwoprimarybuildingblocks:asparse-\nconvolution-basedConvNeXtencoderandalightweightsingle-blockConvNeXt\ndecoder[citeoriginalpaper].Thisautoencoderadoptsanasymmetricarchitecture'

# %% [markdown]
# '5\n.\nFigure 1. The FCMAE framework introduces a fully convolutional masked\nautoencoder designed to learn robust visual representations. The system is composed\nof a ConvNeXt-based encoder that operates using sparse convolutions and a\nlightweight ConvNeXt block serving as the decoder. The architecture is intentionally\nasymmetric: the encoder processes only the unmasked portions of the input image,\nwhile the decoder reconstructs the full image by combining the encoded visible\npatches with the corresponding mask tokens. Importantly, the reconstruction loss is\nappliedsolelytothemasked regions,ensuringthat themodel focuseson inferring the\nmissinginformationratherthanrelyingonthevisiblepixels.\n3.2 Fully Convolutional Masked Autoencoder (FCMAE)\nTheproposedframeworkconsistsoftwoprimarybuildingblocks:asparse-\nconvolution-basedConvNeXtencoderandalightweightsingle-blockConvNeXt\ndecoder[citeoriginalpaper].Thisautoencoderadoptsanasymmetricarchitecture'
