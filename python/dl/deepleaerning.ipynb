# %%
import pandas as pd
import numpy as np
import tensorflow as tf                                                                                  
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#       4 from sklearn.model_selection import train_test_split
#       5 from tensorflow.keras.models import Sequential
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ...

# %%
from sklearn.datasets import load_breast_cancer
df=load_breast_cancer()
x=df.data
y=df.target

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=39,test_size=0.2)

# %%
model=Sequential()
model.add(Dense(24,activation='relu',input_dim=xtrain.shape[1]))
model.add(Dense(8,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                │ (None, 24)             │           744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 8)              │           200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 953 (3.72 KB)
#  Trainable params: 953 (3.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
early=EarlyStopping(monitor='loss',patience=4,verbose=1,restore_best_weights=True)
reduce=ReduceLROnPlateau(monitor='loss',patience=3,factor=0.3,verbose=1)

# %%
model.fit(xtrain,ytrain,epochs=15,batch_size=38,callbacks=[early,reduce])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.fit(xtrain,ytrain,epochs=15,batch_size=38,callbacks=[early,reduce])
#
# NameError: name 'model' is not defined

# %%
accuracy=model.evaluate(xtest,ytest)
accuracy
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9561 - loss: 0.1468
# [0.14682677388191223, 0.9561403393745422]

# %%
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten,Dense

# %%
data=tf.keras.datasets.mnist.load_data()

# %%
(xtrain,ytrain,),(xtest,ytest)=data
xtrain = xtrain / 255.0
xtest = xtest / 255.0

# %%
ytrain
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
xtrain=xtrain.reshape(-1,28,28,1)
xtest=xtest.reshape(-1,28,28,1)
# xtrain= xtrain.reshape(len(xtrain),28*28)

# %%
# ytest.shape(-1,28,28,1)

# %%
# ytrain.shape(-1,28,28,1)

# %%
model=Sequential()
model.add(Conv2D(8,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(MaxPool2D(6,6))
model.add(Flatten())
# model.add(Dense(12,activation="relu"))
model.add(Dense(10,activation="softmax"))

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=['accuracy'])

# %%
model.fit(xtrain,ytrain,epochs=5,callbacks=[reduce,early])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7954 - loss: 0.6936 - learning_rate: 0.0010
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9250 - loss: 0.2574 - learning_rate: 0.0010
# Epoch 3/5
# 1857/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9434 - loss: 0.1953
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9435 - loss: 0.1900 - learning_rate: 0.0010
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9514 - loss: 0.1614 - learning_rate: 3.0000e-04
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
accuracy=model.evaluate(xtest,ytest)
accuracy
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9114 - loss: 0.3161
# [0.31612664461135864, 0.9114000201225281]
